# %%
#hand out cross-validation
#6 features


#0.27158 random forest
#0.38577 linear regression
#0.2832 gradientboostingregressor
#0.2885 AdaBoost
#0.2662225 Extratreesregressor
#0.39669 Lasso alpha=0.1
#0.390406 Lasso alpha=0.01
#0.386372 Lasso alpha=0.005
#0.3334455 SVM
# 0.381239 Ridge alpha=0.1
# 0.381137 Ridge alpha=0.01
# 0.381126 Ridge alpha=0.00006
#0.381772 Ridge alpha=0.6
#0.3506435 DecisionTree 


#7 features
#0.2532472 random forest
#0.2559576726246716 ExtraTreesRegressor
#0.249761975731646 AdaBoostRegressor
#0.38302703846486 Linear Regression
#0.33139127242369626  DecisionTree 
#0.3331583488467244 SVM


#8 features
# 0.2368696810262421 random forest 



# 0.24709224749459424 ExtraTreesRegressor
# 0.26379535538578774 gradientboosting
# 0.25363085562369886 adaboost
# 0.33322918454696976 SVM
#RandomForestRegressor(max_depth=40, max_features=2, min_samples_leaf=2,
                      #min_samples_split=8, n_estimators=200, random_state=100) cv=2
    #0.23408367254112716 mae:0.1776556996742643

#9
#0.24353888770494414random forest
#0.24618797411021365 ExtraTreesRegressor



#10
#0.23748791012626375 ExtraTreesRegressor
#0.23715874911270246 random forest
#0.24081316409199893 GradientBoostingRegressor

#11
#0.24081316409199893 random forest
#0.24118911030522205 Extratrees 
#0.260770867509444 GradientBoosting

#12
# 0.2607163242045993GradientBoosting
# 0.2469536958515439 random forest
# 0.2410543730975932 extratrees

#######################################with Amaxmax and meanstd 
#9
#rmse:0.24025918497512697 r2:0.732243468821433  mae:0.19187719298245612 mape:6340594212219.878 
#rmse:0.08572749251884308  mae:0.06005132158590313 mape:2031579743800.9695 r2:0.9623567575086521




##################WITH std_mean_median in the three directions


#12
#rmse:0.21693422141100563 r2:0.7722026977455794  mae:0.15954492973280518 mape:1.0608530532784042 final model
